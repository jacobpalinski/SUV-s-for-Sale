# %% [markdown]
# ## Extracting SUV Listing Information

# %%
#Import Libraries
import requests
from requests import get
from bs4 import BeautifulSoup
import pandas as pd
import scipy.stats as st
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from time import sleep
from random import randint

# %%
#Establish Headers
headers = {"Accept-Language": "en-US,en;q=0.5",'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36'}

# %%
#Get Data
all_data=[]

pages=np.arange(0,10680,12)

for page in pages:
    page=requests.get("https://www.carsales.com.au/cars/new-south-wales-state/sydney-region/suv-bodystyle/?offset=" 
                      + str(page), headers=headers)
    soup=BeautifulSoup(page.text,'html.parser')
    cars=soup.select('.listing-item')
    sleep(randint(2,5))
    
    for car in cars:
        title=car.select_one('h3 > a').text
        price=car.select_one('.price > a').text
        type_=car.select_one('.seller-type, .franchise-stock-type').get_text(strip=True)
        all_data.append(dict(title=title,price=price,
                             type=type_,**{li['data-type']:li.text for li in car.select('li[data-type]')}))

# %%
#To DataFrame
salesdata=pd.DataFrame(all_data)
print(salesdata.shape)
salesdata.head()
# Out:
# (1014, 8)
#                                                title      price  \
# 0  2019 Land Rover Range Rover Evoque P200 R-Dyna...  $80,900*
# 1        2017 Nissan Patrol Ti Y62 Series 3 Auto 4x4   $75,000
# 2              2018 Audi Q2 35 TFSI design Auto MY19  $42,990*
# 3            2021 Toyota Landcruiser Sahara Auto 4x4  $185,000
# 4       2018 Mazda CX-9 Azami LE TC Auto i-ACTIV AWD  $53,490*
#
#                  type   Odometer Body Style Transmission  \
# 0     Dealer Used Car   5,200 km        SUV    Automatic
# 1  Private Seller Car  96,800 km        SUV    Automatic
# 2     Dealer Used Car  17,870 km        SUV    Automatic
# 3  Private Seller Car      50 km        SUV    Automatic
# 4     Dealer Used Car  36,765 km        SUV    Automatic
#
#                    Engine Build Date
# 0  4cyl 2.0L Turbo Petrol        NaN
# 1        8cyl 5.6L Petrol        NaN
# 2  4cyl 1.4L Turbo Petrol        NaN
# 3  8cyl 4.5L Turbo Diesel        NaN
# 4  4cyl 2.5L Turbo Petrol        NaN

# %% [markdown]
# ## Extensive Data Cleaning

# %%
#Editing Build Dates
salesdata['Build Date'].value_counts()
# Out:
# Build date Apr 2021    11
# Build date Feb 2021     9
# Build date Mar 2021     6
# Build date Dec 2020     6
# Build date Jan 2021     5
# Build date Nov 2020     5
# Build date May 2021     5
# Build date Sep 2020     1
# Build date Aug 2020     1
# Build date Jan 2020     1
# Build date Oct 2020     1
# Build date Jun 2021     1
# Name: Build Date, dtype: int64

# %%
#Build Dates only for SUV's< 1.5 years old
salesdata.drop(columns='Build Date',inplace=True)

# %%
#Creating Column representing Year
salesdata['Year']=[list(x.split(' '))[0] for x in salesdata['title']]

# %%
#Drop body Style
salesdata.drop(columns='Body Style',inplace=True)

# %%
#SUV Brands
salesdata['Brand']=[list(x.split(' '))[1] for x in salesdata['title']]
salesdata['Brand'].unique()
# Out:
# array(['Land', 'Nissan', 'Audi', 'Toyota', 'Mazda', 'Mercedes-Benz',
#        'Mitsubishi', 'MINI', 'Alfa', 'Volkswagen', 'BMW', 'Lexus',
#        'Honda', 'Hyundai', 'Kia', 'Jeep', 'Dodge', 'Subaru', 'Porsche',
#        'Ford', 'Holden', 'SKODA', 'MG', 'Volvo', 'Jaguar', 'Suzuki',
#        'Isuzu', 'INFINITI', 'SsangYong', 'Tesla', 'Maserati', 'LDV',
#        'Haval', 'Renault', 'Peugeot', 'Lamborghini'], dtype=object)

# %%
#Replace Land with Land Rover
salesdata['Brand'].replace('Land','Land Rover',inplace=True)

# %%
#Retreive Model Type from Title
salesdata['Modellst']=[list(x.split(' '))[2:] for x in salesdata['title']]
salesdata['Modellst']=[x[:] if x[0]!='Rover' else x[1:] for x in salesdata['Modellst']]
salesdata['Model']=[' '.join(x) for x in salesdata['Modellst']]
salesdata.drop(columns='Modellst',inplace=True)

# %%
#Null Odometers
Nullodom=salesdata[salesdata['Odometer'].isnull()]
Nullodom['Year'].value_counts()
# Out:
# 2021    37
# 2020    15
# 2019     2
# Name: Year, dtype: int64

# %%
#Only recent models with no odometers so assume they are 0
salesdata['Odometer'].fillna(0,inplace=True)

# %%
#Reformating Odometer Values
salesdata.dtypes['Odometer']
# Out:
# dtype('O')

# %%
#Eliminating ',' and 'km' from odometer figures
salesdata['Odometer']=salesdata['Odometer'].astype(str)
salesdata['Odometer']=salesdata['Odometer'].map(lambda x: x.strip('km'))
salesdata['Odometer']=salesdata['Odometer'].map(lambda x: x.replace(',',''))
salesdata['Odometer']=salesdata['Odometer'].astype(int)

# %%
#Formatting Price Figures
salesdata['price']=salesdata['price'].astype(str)
salesdata['price']=salesdata['price'].map(lambda x: x.strip('$'))
salesdata['price']=salesdata['price'].map(lambda x: x.replace('*',''))
salesdata['price']=salesdata['price'].map(lambda x: x.replace(',',''))
salesdata['price'].unique()
# Out:
# array(['80900 ', '75000 ', '42990 ', '185000 ', '53490 ', '69000 ',
#        '139900 ', '25880 ', '23990 ', '29990 ', '54888 ', '52880 ',
#        '45700 ', '39640 ', '108000 ', '69888 ', '34850 ', '46990 ',
#        '59990 ', '59888 ', '39990 ', '38285 ', '25888 ', '64900 ',
#        '59800 ', '19990 ', '17995 ', '109990 ', '64500 ', '47888 ',
#        '46888 ', '10000 ', '59900 ', '29000 ', '28990 ', '26880 ',
#        '105990 ', '40888 ', '35447 ', '34999 ', '65837 ', '61990 ',
#        '56888 ', '43777 ', '42800 ', '25990 ', '22490 ', '22000 ',
#        '7900 ', '69990 ', '69500 ', '31990 ', '31790 ', '19880 ',
#        '159888 ', '45999 ', '43850 ', '41880 ', '36065 ', '28500 ',
#        '17880 ', '66888 ', '65000 ', '64990 ', '63985 ', '34800 ',
#        '66880 ', '44850 ', '57800 ', '47988 ', '46500 ', '14000 ',
#        '66990 ', '40999 ', '39888 ', '28888 ', '169800 ', '47990 ',
#        '47160 ', '34990 ', '27490 ', '56800 ', '35500 ', '20750 ',
#        '39180 ', '30490 ', '27987 ', '26888 ', '21250 ', '99650 ',
#        '92900 ', '79900 ', '44980 ', '39056 ', '35990 ', '31980 ',
#        '28650 ', '21888 ', '57990 ', '47700 ', '36650 ', '33990 ',
#        '28390 ', '25980 ', '99990 ', '89800 ', '72990 ', '71888 ',
#        '57000 ', '48800 ', '39650 ', '35000 ', '30000 ', '210000 ',
#        '149800 ', '125000 ', '82878 ', '55990 ', '52990 ', '49888 ',
#        '47490 ', '47263 ', '38788 ', '36023 ', '31500 ', '19888 ',
#        '12490 ', '129850 ', '96490 ', '83320 ', '80000 ', '78880 ',
#        '76950 ', '66500 ', '50227 ', '48332 ', '42620 ', '35868 ',
#        '35648 ', '34185 ', '15777 ', '95990 ', '86500 ', '73888 ',
#        '64490 ', '56850 ', '45940 ', '24999 ', '22888 ', '21950 ',
#        '16777 ', '9950 ', '479990 ', '172590 ', '95000 ', '57280 ',
#        '51478 ', '49000 ', '48777 ', '39550 ', '36800 ', '36000 ',
#        '26400 ', '26048 ', '24980 ', '19980 ', '15888 ', '219990 ',
#        '165888 ', '137990 ', '131878 ', '104062 ', '93000 ', '48850 ',
#        '44890 ', '40097 ', '19987 ', '9900 ', '4990 ', '119990 ',
#        '70880 ', '40139 ', '35880 ', '30690 ', '12998 ', '122990 ',
#        '108500 ', '89500 ', '83990 ', '49950 ', '39590 ', '25400 ',
#        '21700 ', '17900 ', '16990 ', '15990 ', '14990 ', '165000 ',
#        '73985 ', '73706 ', '62990 ', '53900 ', '35888 '], dtype=object)

# %%
#Drop Data Entry enquire for price
salesdata=salesdata[salesdata['price']!='Enquire for price ']
salesdata['price']=salesdata['price'].astype(int)

# %%
#Title Column no longer required
salesdata.drop(columns='title',inplace=True)

# %%
#Type of Sale
salesdata['type'].value_counts()
# Out:
# Dealer Used Car        491
# Private Seller Car     311
# Dealer Demo             84
# New Car In Stock        45
# Dealer Used Car4.2      26
# Dealer Used Car4.7      12
# Dealer Used Car4.3      10
# Dealer Used Car4.6       9
# Dealer Demo4.7           6
# New Car In Stock4.7      6
# Dealer Demo4.5           3
# Dealer Used Car4.8       2
# Dealer Used Car3.9       2
# Dealer Demo4.2           2
# Dealer Used Car3.8       2
# New Car In Stock4.5      2
# New Car In Stock4.2      1
# Name: type, dtype: int64

# %%
#Replacing Type Values
Dealer_Used=['Dealer Used Car4.2','Dealer Used Car4.7','Dealer Used Car4.3','Dealer Used Car4.6',
             'Dealer Used Car3.9','Dealer Used Car4.8','Dealer Used Car3.8']
for x in Dealer_Used:
    salesdata['type'].replace(x,'Dealer Used Car',inplace=True)

New_Stock=['New Car In Stock4.7','New Car In Stock4.5','New Car In Stock4.2']
for y in New_Stock:
    salesdata['type'].replace(y,'New Car In Stock',inplace=True)

Dealer_Demo=['Dealer Demo4.5','Dealer Demo4.2','Dealer Demo4.7']
for z in Dealer_Demo:
    salesdata['type'].replace(z,'Dealer Demo',inplace=True)

# %%
salesdata.head()
# Out:
#     price                type  Odometer Transmission                  Engine  \
# 0   80900     Dealer Used Car      5200    Automatic  4cyl 2.0L Turbo Petrol
# 1   75000  Private Seller Car     96800    Automatic        8cyl 5.6L Petrol
# 2   42990     Dealer Used Car     17870    Automatic  4cyl 1.4L Turbo Petrol
# 3  185000  Private Seller Car        50    Automatic  8cyl 4.5L Turbo Diesel
# 4   53490     Dealer Used Car     36765    Automatic  4cyl 2.5L Turbo Petrol
#
#    Year       Brand                                              Model
# 0  2019  Land Rover  Range Rover Evoque P200 R-Dynamic S Auto 4x4 MY20
# 1  2017      Nissan                    Patrol Ti Y62 Series 3 Auto 4x4
# 2  2018        Audi                        Q2 35 TFSI design Auto MY19
# 3  2021      Toyota                        Landcruiser Sahara Auto 4x4
# 4  2018       Mazda                  CX-9 Azami LE TC Auto i-ACTIV AWD

# %%
#Renaming and Rearranging columns in Python
salesdata.rename(columns={'price':'Price($)','type':'Type','Odometer':'Odometer(km)'},inplace=True)
salesdata=salesdata[['Brand','Year','Model','Price($)','Odometer(km)','Transmission','Engine','Type']]
salesdata.head()
# Out:
#         Brand  Year                                              Model  \
# 0  Land Rover  2019  Range Rover Evoque P200 R-Dynamic S Auto 4x4 MY20
# 1      Nissan  2017                    Patrol Ti Y62 Series 3 Auto 4x4
# 2        Audi  2018                        Q2 35 TFSI design Auto MY19
# 3      Toyota  2021                        Landcruiser Sahara Auto 4x4
# 4       Mazda  2018                  CX-9 Azami LE TC Auto i-ACTIV AWD
#
#    Price($)  Odometer(km) Transmission                  Engine  \
# 0     80900          5200    Automatic  4cyl 2.0L Turbo Petrol
# 1     75000         96800    Automatic        8cyl 5.6L Petrol
# 2     42990         17870    Automatic  4cyl 1.4L Turbo Petrol
# 3    185000            50    Automatic  8cyl 4.5L Turbo Diesel
# 4     53490         36765    Automatic  4cyl 2.5L Turbo Petrol
#
#                  Type
# 0     Dealer Used Car
# 1  Private Seller Car
# 2     Dealer Used Car
# 3  Private Seller Car
# 4     Dealer Used Car

# %%
#Price and Year Dtypes
salesdata[['Price($)','Year']].dtypes
# Out:
# Price($)     int32
# Year        object
# dtype: object

# %%
#Year to int
salesdata['Year']=salesdata['Year'].astype(int)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#Distribution of SUV Prices
plt.figure(figsize=(12,6))
plt.title('SUV Price Distribution')
sns.distplot(salesdata['Price($)'],hist_kws={'edgecolor':'black','alpha':0.2},kde_kws={'color':'Green'})
# Out:
# C:\Users\kpali\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'SUV Price Distribution'}, xlabel='Price($)', ylabel='Density'>

# %%
#Summary of Prices
salesdata['Price($)'].describe()
# Out:
# count      1014.000000
# mean      55984.994083
# std       40888.079220
# min        4400.000000
# 25%       29575.000000
# 50%       44985.000000
# 75%       69500.000000
# max      479990.000000
# Name: Price($), dtype: float64

# %%
#Price Distribution by Car Brand
plt.figure(figsize=(12,6))
plt.xticks(rotation=80)
plt.title('SUV Prices by Brand')
sns.boxplot(x='Brand',y='Price($)',data=salesdata)
# Out:
# <AxesSubplot:title={'center':'SUV Prices by Brand'}, xlabel='Brand', ylabel='Price($)'>

# %%
# Most Common Brands
from collections import Counter
common_brands=salesdata['Brand'].values.tolist()
Counter(common_brands).most_common(15)
# Out:
# [('Toyota', 132),
#  ('Mazda', 86),
#  ('BMW', 76),
#  ('Land Rover', 75),
#  ('Mercedes-Benz', 75),
#  ('Audi', 74),
#  ('Volkswagen', 68),
#  ('Nissan', 49),
#  ('Hyundai', 48),
#  ('Subaru', 37),
#  ('Mitsubishi', 34),
#  ('Jeep', 33),
#  ('Porsche', 28),
#  ('Kia', 24),
#  ('Ford', 22)]

# %%
#Distribution of Odometer Readings >0
positive_odom=salesdata[salesdata['Odometer(km)']>0]
positive_odom['Odometer(km)']=positive_odom['Odometer(km)'].astype(int)
plt.figure(figsize=(12,6))
plt.title('Distribution of Odometer Readings > 0km')
plt.hist(positive_odom['Odometer(km)'],bins=20,density=True,color='Grey',edgecolor='Black')
# Out:
# <ipython-input-29-ded8439e20c6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_odom['Odometer(km)']=positive_odom['Odometer(km)'].astype(int)
# (array([1.14150019e-05, 7.37851834e-06, 8.02956407e-06, 5.59899333e-06,
#         2.86460124e-06, 2.38716770e-06, 1.47570367e-06, 9.98270128e-07,
#         3.90627441e-07, 4.77433540e-07, 8.68060981e-08, 8.68060981e-08,
#         1.30209147e-07, 1.30209147e-07, 4.34030490e-08, 8.68060981e-08,
#         0.00000000e+00, 0.00000000e+00, 4.34030490e-08, 4.34030490e-08]),
#  array([3.0000000e+00, 2.4002850e+04, 4.8002700e+04, 7.2002550e+04,
#         9.6002400e+04, 1.2000225e+05, 1.4400210e+05, 1.6800195e+05,
#         1.9200180e+05, 2.1600165e+05, 2.4000150e+05, 2.6400135e+05,
#         2.8800120e+05, 3.1200105e+05, 3.3600090e+05, 3.6000075e+05,
#         3.8400060e+05, 4.0800045e+05, 4.3200030e+05, 4.5600015e+05,
#         4.8000000e+05]),
#  <BarContainer object of 20 artists>)

# %%
#Summary of Odometer Readings
salesdata['Odometer(km)'].describe()
# Out:
# count      1014.000000
# mean      62514.392505
# std       61292.575053
# min           0.000000
# 25%       14719.500000
# 50%       49802.500000
# 75%       89020.250000
# max      480000.000000
# Name: Odometer(km), dtype: float64

# %%
#Correlation Between Columns
salesdata.corr()
# Out:
#                   Year  Price($)  Odometer(km)
# Year          1.000000  0.339769     -0.856559
# Price($)      0.339769  1.000000     -0.337396
# Odometer(km) -0.856559 -0.337396      1.000000

# %%
#Relationship between Odometer Readings and Price
plt.figure(figsize=(12,6))
plt.title('Odometer Reading vs Price')
sns.scatterplot(x='Odometer(km)',y='Price($)',data=salesdata,hue='Transmission')
print('R Squared', st.pearsonr(salesdata['Odometer(km)'],salesdata['Price($)']))
# Out:
# R Squared (-0.3373960283046009, 2.0414855760835114e-28)

# %%
#Median Price by Year
plt.figure(figsize=(12,6))
plt.title('Average Car Price per Year')
plt.xlim(salesdata['Year'].max(),salesdata['Year'].min())
sns.lineplot(x='Year',y='Price($)',data=salesdata,estimator='median',ci=None)
# Out:
# <AxesSubplot:title={'center':'Average Car Price per Year'}, xlabel='Year', ylabel='Price($)'>

# %%
#Price Quantiles
price_quantiles=salesdata['Price($)'].quantile([0.25,0.5,0.75])

# %%
#Brands in Each Quartile
brand_1=[]
brand_2=[]
brand_3=[]
brand_4=[]

brands=salesdata['Brand'].unique()

for x in brands:
    if salesdata[salesdata['Brand']== x]['Price($)'].median() <= price_quantiles[0.25]:
        brand_1.append(x)
    if salesdata[salesdata['Brand']== x]['Price($)'].median() > price_quantiles[0.25] and salesdata[salesdata['Brand']== x]['Price($)'].median() <= price_quantiles[0.5]:
        brand_2.append(x)
    if salesdata[salesdata['Brand']== x]['Price($)'].median() > price_quantiles[0.5] and salesdata[salesdata['Brand']== x]['Price($)'].median() <= price_quantiles[0.75]:
        brand_3.append(x)
    if salesdata[salesdata['Brand']== x]['Price($)'].median() > price_quantiles[0.75]:
        brand_4.append(x)

# %%
#Depreciation 1st Quartile
df=salesdata[salesdata['Brand'].isin(brand_1)]
plt.figure(figsize=(12,6))
plt.title('Depreciation of 1st Quartile Brands')
plt.xlim(df['Year'].max(),df['Year'].min())
sns.lineplot(x='Year',y='Price($)',hue='Brand',data=df,estimator='mean',ci=None)
# Out:
# <AxesSubplot:title={'center':'Depreciation of 1st Quartile Brands'}, xlabel='Year', ylabel='Price($)'>

# %%
#Depreciation in 2nd Quartile
df=salesdata[salesdata['Brand'].isin(brand_2)]
plt.figure(figsize=(12,6))
plt.title('Depreciation of 2nd Quartile Brands')
plt.xlim(df['Year'].max(),df['Year'].min())
sns.lineplot(x='Year',y='Price($)',hue='Brand',data=df,estimator='mean',ci=None)
# Out:
# <AxesSubplot:title={'center':'Depreciation of 2nd Quartile Brands'}, xlabel='Year', ylabel='Price($)'>

# %%
#Depreciation in 3rd Quartile
df=salesdata[salesdata['Brand'].isin(brand_3)]
plt.figure(figsize=(12,6))
plt.title('Depreciation of 3rd Quartile Brands')
plt.xlim(df['Year'].max(),df['Year'].min())
sns.lineplot(x='Year',y='Price($)',hue='Brand',data=df,estimator='mean',ci=None)
# Out:
# <AxesSubplot:title={'center':'Depreciation of 3rd Quartile Brands'}, xlabel='Year', ylabel='Price($)'>

# %%
#Depreciation in 4th Quartile
df=salesdata[salesdata['Brand'].isin(brand_4)]
plt.figure(figsize=(12,6))
plt.title('Depreciation of 4th Quartile Brands')
plt.xlim(df['Year'].max(),df['Year'].min())
sns.lineplot(x='Year',y='Price($)',hue='Brand',data=df,estimator='mean',ci=None)
# Out:
# <AxesSubplot:title={'center':'Depreciation of 4th Quartile Brands'}, xlabel='Year', ylabel='Price($)'>
